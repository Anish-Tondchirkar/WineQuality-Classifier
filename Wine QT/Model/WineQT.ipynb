# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv(r'C:\Users\Anish Tondchirkar\Coding\Data Science and ML\PROJECTS\Wine QT\Data\WineQT.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df = df.drop('Id',axis=1)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# #### Data Cleaning & preprocessing

# %%
# Checking missing Values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.shape
# Out:
# (1143, 12)

# %%
# Count of qulaity
sns.catplot(x='quality',data=df,kind='count')

# %%
sns.barplot(x='quality',y='fixed acidity',data=df)
# as u can see the plot...for every quality of wine the fixed acidity is approx 7 8 9...so potentially we can drop the column
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
# Volatile acidity vs quality are inversely proportional
sns.barplot(x='quality',y='volatile acidity',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
# Citric acid vs quality...directly prop
sns.barplot(x='quality',y='citric acid',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
# residual sugar vs quality...mo effect...
sns.barplot(x='quality',y='residual sugar',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
# chlorides vs quality ...invesely prop
sns.barplot(x='quality',y='chlorides',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
# free sulfur dioxide vs quali...normal distri
sns.barplot(x='quality',y='free sulfur dioxide',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
# total sulfur dioxide vs quality...normal
sns.barplot(x='quality',y='total sulfur dioxide',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
# pH vs quality...no effect
sns.barplot(x='quality',y='pH',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
# sulphates vs quality...diectly
sns.barplot(x='quality',y='sulphates',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
# alcohol vs quality..no use or maybe directly prop
sns.barplot(x='quality',y='alcohol',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# #### Correlation
# ##### it is studied using corr method and heatmaps

# %%
correlation = df.corr()

# %%
sns.heatmap(correlation, cbar=True, square=True, fmt = '.1f', annot = True, annot_kws={'size':8}, cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# #### Data Preprocessing

# %%
# Features to be removed based on weak correlation with quality
ft = ['fixed acidity','residual sugar','pH','chlorides','free sulfur dioxide']

# Removing the features
df_final = df.drop(columns=ft)

# Verify the new DataFrame
print(df_final.head())
# Out:
#    volatile acidity  citric acid  total sulfur dioxide  density  sulphates  \
# 0              0.70         0.00                  34.0   0.9978       0.56
# 1              0.88         0.00                  67.0   0.9968       0.68
# 2              0.76         0.04                  54.0   0.9970       0.65
# 3              0.28         0.56                  60.0   0.9980       0.58
# 4              0.70         0.00                  34.0   0.9978       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X = df_final.iloc[:, :-1].values
# y = df_final.iloc[:, -1].values

# %%
# Quality are 3 4 5 6 7 8 so categorising as good 1(7 and above) and bad(less than 7)
y = df_final['quality'].apply(lambda y: 1 if y >= 7 else 0)

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 11)

# %%
df_final
# Out:
#       volatile acidity  citric acid  total sulfur dioxide  density  sulphates  \
# 0                0.700         0.00                  34.0  0.99780       0.56
# 1                0.880         0.00                  67.0  0.99680       0.68
# 2                0.760         0.04                  54.0  0.99700       0.65
# 3                0.280         0.56                  60.0  0.99800       0.58
# 4                0.700         0.00                  34.0  0.99780       0.56
# ...                ...          ...                   ...      ...        ...
# 1138             0.510         0.13                  40.0  0.99574       0.75
# 1139             0.620         0.08                  38.0  0.99651       0.82
# 1140             0.600         0.08                  44.0  0.99490       0.58
# 1141             0.550         0.10                  51.0  0.99512       0.76
# 1142             0.645         0.12                  44.0  0.99547       0.71
#
#       alcohol  quality
# ...

# %% [markdown]
# #### Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
# Create a StandardScaler
scaler = StandardScaler()

# Fit and transform the selected columns
X_train_final = scaler.fit_transform(X_train)
X_test_final = scaler.transform(X_test)

# %% [markdown]
# #### Training

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state = 7)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=7)

# %% [markdown]
# #### Evaluation

# %%
# predictions on test data
y_pred = model.predict(X_test_final)

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# %%
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8471615720524017

# %% [markdown]
# #### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(model, X_train_final, y_train, cv=5, scoring='accuracy')
print(f'Cross-Validation Accuracy Scores: {cv_scores}')
print(f'Mean CV Accuracy: {cv_scores.mean()}')
# Out:
# Cross-Validation Accuracy Scores: [0.85245902 0.92349727 0.89617486 0.90710383 0.87912088]
# Mean CV Accuracy: 0.8916711703596949

# %% [markdown]
# #### Predictor

# %%
user_input = (0.28,0.56,60.0,0.9980,0.58,9.8)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(user_input)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = model.predict(input_data_reshaped)
# print(prediction)

if prediction[0] == 0:
    print("Bad Wine Quality")
else:
    print("Goooood Quality Wine")
# Out:
# Bad Wine Quality
